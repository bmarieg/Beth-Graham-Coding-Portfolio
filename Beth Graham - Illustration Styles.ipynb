# %% [markdown]
# # Beth Graham - Illustration Styles

# %% [markdown]
# ## Molecular Biology

# %% [markdown]
# ![Figure%206%20Atlastin.png](attachment:Figure%206%20Atlastin.png)

# %% [markdown]
# ## Colored Pencil

# %% [markdown]
# ![Hummingbird%20small.jpg](attachment:Hummingbird%20small.jpg)

# %% [markdown]
# ## Vector Graphics

# %% [markdown]
# ![Musk%20ox%20small-01.jpg](attachment:Musk%20ox%20small-01.jpg)

# %% [markdown]
# ## Art Marker

# %% [markdown]
# ![Bonnet%20small.jpg](attachment:Bonnet%20small.jpg)
